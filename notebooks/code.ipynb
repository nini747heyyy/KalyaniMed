# %%
pip install torch torchvision medminst opencv-python matplotlib scikit-learn numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement medminst (from versions: none)
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for medminst
